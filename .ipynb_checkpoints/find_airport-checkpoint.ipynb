# %%
# Find lat long of NY Airport
# Dependencies
import requests
import json

# Google developer API key
from config import gkey

# Target city
target_apt = "Airport, New York"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_apt, gkey)

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()

# Print the json
print(geo_data)
# Out:
# {'results': [{'address_components': [{'long_name': 'John F. Kennedy International Airport', 'short_name': 'JFK International Airport', 'types': ['airport', 'establishment', 'point_of_interest']}, {'long_name': 'Queens', 'short_name': 'Queens', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Queens County', 'short_name': 'Queens County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '11430', 'short_name': '11430', 'types': ['postal_code']}], 'formatted_address': 'John F. Kennedy International Airport (JFK), Queens, NY 11430, USA', 'geometry': {'location': {'lat': 40.6413111, 'lng': -73.77813909999999}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 40.64266008029149, 'lng': -73.7767901197085}, 'southwest': {'lat': 40.63996211970849, 'lng': -73.7794880802915}}}, 'place_id': 'ChIJR0lA1VBmwokR8BGfSBOyT-w', 'plus_code': {'compound_code': 'J6RC+GP New York, United States', 'global_code': '87G8J6RC+GP'}, 'types': ['airport', 'establishment', 'point_of_interest']}], 'status': 'OK'}

# %%
# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "John F. Kennedy International Airport",
#                     "short_name": "JFK International Airport",
#                     "types": [
#                         "airport",
#                         "establishment",
#                         "point_of_interest"
#                     ]
#                 },
#                 {
#                     "long_name": "Queens",
#                     "short_name": "Queens",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_1"
#                     ]
#                 },
#                 {
#                     "long_name": "Queens County",
#                     "short_name": "Queens County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "New York",
#                     "short_name": "NY",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "11430",
#                     "short_name": "11430",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "John F. Kennedy International Airport (JFK), Queens, NY 11430, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 40.6413111,
#                     "lng": -73.77813909999999
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.64266008029149,
#                         "lng": -73.7767901197085
#                     },
#                     "southwest": {
#                         "lat": 40.63996211970849,
#                         "lng": -73.7794880802915
#                     }
#                 }
#             },
#             "place_id": "ChIJR0lA1VBmwokR8BGfSBOyT-w",
#             "plus_code": {
#                 "compound_code": "J6RC+GP New York, United States",
#                 "global_code": "87G8J6RC+GP"
#             },
#             "types": [
#                 "airport",
#                 "establishment",
#                 "point_of_interest"
#             ]
#         }
#     ],
#     "status": "OK"
# }

# %%
# Extract latitude and longitude
lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print('''
    City: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_apt, lat, lng))
# Out:
#     City: Airport, New York
#     Latitude: 40.6413111
#     Longitude: -73.77813909999999

# %%
target_coordinates = f"{lat}, {lng}"
print(target_coordinates)
# Out:
# 40.6413111, -73.77813909999999

# %%
# geocoordinates
#target_coordinates = "43.6187102, -116.2146068"
target_coordinates = f"{lat}, {lng}"
target_search = "Airport"
target_radius = 80000
target_type = "airport"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.6413111,
#                     "lng": -73.77813909999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.6635108,
#                         "lng": -73.7634474
#                     },
#                     "southwest": {
#                         "lat": 40.63391119999999,
#                         "lng": -73.82221419999999
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "87586c86ef1c53323d31eba8260ca7f0ea7cb094",
#             "name": "John F. Kennedy International Airport",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101154712852857841718/photos\">Mercedes Ramirez Guerrero</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAdQr_tQNMzGXIINHXjzwpUM4F4X--o78iR5ocpZTNhkYp4bhpSFuOFd72g4Rm4rieJ-opoECgrsPv6z23HngHF0M91dYVOGlP1JLKwtBKd4eSIOJyS1mGB54gOM0WM199EhDHT0Sog8Gf1Mf7iww9DXmIGhT89-TJ8sJnRIEac9EbekKpOdcbYg",
#                     "width": 5184
#                 }
#             ],
#             "place_id": "ChIJR0lA1VBmwokR8BGfSBOyT-w",
#             "plus_code": {
#                 "compound_code": "J6RC+GP New York",
#                 "global_code": "87G8J6RC+GP"
#             },
#             "rating": 3.7,
#             "reference": "ChIJR0lA1VBmwokR8BGfSBOyT-w",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8795,
#             "vicinity": "Queens"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.6895314,
#                     "lng": -74.1744624
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.69546885,
#                         "lng": -74.1670314
#                     },
#                     "southwest": {
#                         "lat": 40.68755225000001,
#                         "lng": -74.1967554
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "8d57add005d7717b94e463fe24b9825cdd909afc",
#             "name": "Newark Liberty International Airport",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109316008140528604052/photos\">Jhonattan Pel\u00e1ez</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAvrTWcDygFY3tLN5mNYN6NTNt0V9FBosTTt7SOiXZccqJ-558cWenCMs2rwuK3k3tcF4MLs8cdqsa8Ls30YZ8rWNPPYulCuKkH_T4b2BfofISjErzjapRUZzfD66HhljjEhAJV3A1-6GMjlHzriKfg78GGhT4pOOGS-jIwm2P2DTy1az0y1D8gg",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJ7wzsxeFSwokRhvLXxTe087M",
#             "plus_code": {
#                 "compound_code": "MRQG+R6 Newark, New Jersey",
#                 "global_code": "87G7MRQG+R6"
#             },
#             "rating": 3.1,
#             "reference": "ChIJ7wzsxeFSwokRhvLXxTe087M",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5230,
#             "vicinity": "3 Brewster Rd, Newark"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.7769271,
#                     "lng": -73.8739659
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.7796712,
#                         "lng": -73.87067474999998
#                     },
#                     "southwest": {
#                         "lat": 40.76869480000001,
#                         "lng": -73.87506295000001
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "f8eabf71af15bb6c56ec923bf2e475ca3a39f3b2",
#             "name": "LaGuardia Airport",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109750031497929070715/photos\">Ignacio Garcia</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA6BeyiwoKPOyAo65MTBgeGHj-uxeEbSZbdWvBRDi4Ga5V05e7XmqIUj6gFDPm8Aquqc1550b37vAvL6OP28YZDUvvYbnVkIdNHftjTTnJact3kl_MkCe1ef0a-YDCAUWlEhCXskqVTFgLB6ipyroNFbeiGhSPl-Nq8bifBF1vrRpjFU7y3C3bkA",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJtU1Cg4lfwokRs2aWDmbEL3c",
#             "plus_code": {
#                 "compound_code": "Q4GG+QC New York",
#                 "global_code": "87G8Q4GG+QC"
#             },
#             "rating": 2.8,
#             "reference": "ChIJtU1Cg4lfwokRs2aWDmbEL3c",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4063,
#             "vicinity": "Queens"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.0683325,
#                     "lng": -73.7086641
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.0746118,
#                         "lng": -73.70437935000001
#                     },
#                     "southwest": {
#                         "lat": 41.06623939999999,
#                         "lng": -73.71009234999998
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "926f7656bd53d39eb22c151d4b5ccf21c04f821a",
#             "name": "Westchester County Airport",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1458,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112110162861336990395/photos\">Ahmed Allam</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAlTJOhMW9NZqI8Ol2qVLWKTt6W0qhXrtzAgxufGmMcBo0QG_gAlLLuCfMw2E28u1qhulZetvCqfKQNKM6DX_DJne-MKNmo-JYO32-ewE6X38ALXcFcZSSAgfIfAkw4ycGEhCPLM94UoYvtWcZterS4sGQGhTdp8tqz5iIS4NSS-tyc50Rj_Cv8Q",
#                     "width": 1698
#                 }
#             ],
#             "place_id": "ChIJdZWrbymWwokRbck_om4HQ80",
#             "plus_code": {
#                 "compound_code": "379R+8G Harrison, NY",
#                 "global_code": "87H8379R+8G"
#             },
#             "rating": 4,
#             "reference": "ChIJdZWrbymWwokRbck_om4HQ80",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 292,
#             "vicinity": "240 Airport Rd, White Plains"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.858332,
#                     "lng": -74.061497
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.85978147989272,
#                         "lng": -74.06031982010728
#                     },
#                     "southwest": {
#                         "lat": 40.85708182010728,
#                         "lng": -74.06301947989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "e14e7f78bfd71f632f439abc6435c27436ba0b40",
#             "name": "Teterboro Airport",
#             "photos": [
#                 {
#                     "height": 666,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117036294288612116181/photos\">Michael Caruso</a>"
#                     ],
#                     "photo_reference": "CmRaAAAACQOKjrNjLJRQdp1ky2qgNC5Kh4nvE21613DW1pam7bHi3dcqeFPfU5DdVd0ttO88pq9RxsbwEf_G1-ppNOtyOlVexCNsN9zc_DcTvAulxQUCGUffWhWNoyr_NEVwMfn3EhBhrAt_ItC7VOlHK2d5NmlVGhSiH2IijZrP7DyW5EE7uv1p3ZcgfA",
#                     "width": 879
#                 }
#             ],
#             "place_id": "ChIJa1Kd8bH5wokRe4-wPDy4pE8",
#             "plus_code": {
#                 "compound_code": "VW5Q+8C Teterboro, New Jersey",
#                 "global_code": "87G7VW5Q+8C"
#             },
#             "rating": 4.3,
#             "reference": "ChIJa1Kd8bH5wokRe4-wPDy4pE8",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 109,
#             "vicinity": "111 Industrial Ave, Teterboro"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.7261266,
#                     "lng": -73.4167921
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.72747462989273,
#                         "lng": -73.41560207010728
#                     },
#                     "southwest": {
#                         "lat": 40.72477497010728,
#                         "lng": -73.41830172989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "978d4e63d36671dea86b58fa1c43679253245304",
#             "name": "Republic Airport",
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113805831175193784510/photos\">chris yanaros</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA2Z_pCTA5NbYoP_BML6DCCuecQevpz3udMVeDv_SwaEv3YF7ISR3Nz8AFAwBUTE-_r6BjjLHc7RmUV6HTFe3LzNVU3URA-gLzwnuFGyTdJzSTcaDr-j4325HwD6TGBrN3EhCvr92HJKyoV2LFtNXsi5-RGhRfNhszE_VR0U-XrFgezQxJLEXcrQ",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJQ8s5jyEr6IkR5SSpQXOhgQE",
#             "plus_code": {
#                 "compound_code": "PHGM+F7 East Farmingdale, Babylon, NY",
#                 "global_code": "87G8PHGM+F7"
#             },
#             "rating": 4.3,
#             "reference": "ChIJQ8s5jyEr6IkR5SSpQXOhgQE",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 53,
#             "vicinity": "7150 Republic Airport, Farmingdale"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.6903683,
#                     "lng": -74.1775846
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.69185787989273,
#                         "lng": -74.17655487010727
#                     },
#                     "southwest": {
#                         "lat": 40.68915822010728,
#                         "lng": -74.17925452989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "2a820cf3b5e95afd14925f32ba726282f9d01644",
#             "name": "Newark international airport",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106163940790398630723/photos\">Zhou Dong</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAwkcmPgGLydEX6Ib9EGxIx5DW7Nc_SBKS8HX_RoPUdNMQOH3f5b5WaGTNRB9ihPZociYddVM0CavSePsCwGLHID_hBGU2JhlqcrZpeBrN_ibVFvdkgwi2ZUafaoJnayQFEhDwiz8VMNnCiKVL8ubS2cwPGhQeUfGrEoBdUuO3Ud1ZZWvFezPSNg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ_Qpf5L5TwokRBBlhAxzivp0",
#             "plus_code": {
#                 "compound_code": "MRRC+4X Newark, New Jersey",
#                 "global_code": "87G7MRRC+4X"
#             },
#             "rating": 3.1,
#             "reference": "ChIJ_Qpf5L5TwokRBBlhAxzivp0",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 12,
#             "vicinity": "U.S. 1 Truck, Newark"
#         }
#     ],
#     "status": "OK"
# }
